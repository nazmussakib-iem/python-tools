# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_stata("oldrdd.dta")

# %%
df
# Out:
#                       oldallowance  amountOld        ID  TERM    PSU   HHID  \
# 0                              0.0        NaN    1045.0   1.0    1.0   45.0
# 1                              0.0        NaN    1065.0   1.0    1.0   65.0
# 2                              0.0        NaN    1100.0   1.0    1.0  100.0
# 3                              0.0        NaN    2103.0   3.0    2.0  103.0
# 4                              0.0        NaN    3106.0  12.0    3.0  106.0
# ...                            ...        ...       ...   ...    ...    ...
# 1720  Elderly Allowance Activities     3000.0  720013.0  13.0  720.0   13.0
# 1721  Elderly Allowance Activities     3000.0  720052.0  13.0  720.0   52.0
# 1722                           0.0        NaN  720059.0  13.0  720.0   59.0
# 1723                           0.0        NaN  720064.0  13.0  720.0   64.0
# 1724                           0.0        NaN  720071.0  13.0  720.0   71.0
#
# ...

# %%
df['oldallowance'].count()
# Out:
# np.int64(1725)

# %%
df
# Out:
#                       oldallowance  amountOld        ID  TERM    PSU   HHID  \
# 0                              0.0        NaN    1045.0   1.0    1.0   45.0
# 1                              0.0        NaN    1065.0   1.0    1.0   65.0
# 2                              0.0        NaN    1100.0   1.0    1.0  100.0
# 3                              0.0        NaN    2103.0   3.0    2.0  103.0
# 4                              0.0        NaN    3106.0  12.0    3.0  106.0
# ...                            ...        ...       ...   ...    ...    ...
# 1720  Elderly Allowance Activities     3000.0  720013.0  13.0  720.0   13.0
# 1721  Elderly Allowance Activities     3000.0  720052.0  13.0  720.0   52.0
# 1722                           0.0        NaN  720059.0  13.0  720.0   59.0
# 1723                           0.0        NaN  720064.0  13.0  720.0   64.0
# 1724                           0.0        NaN  720071.0  13.0  720.0   71.0
#
# ...

# %%
df['treatment'] = df['oldallowance'].apply(lambda x: 0 if x == 0 else 1)

# %%
df['treatment']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1720    1
# 1721    1
# 1722    0
# 1723    0
# 1724    0
# Name: treatment, Length: 1725, dtype: category
# Categories (2, int64): [0 < 1]

# %%
rdd_plot(
    data=df,
    outcome_variable='HospitalStay',  # Outcome variable
    running_variable='land',   # Running variable
    cutoff= 0.501,                       # Cutoff for RDD
    fuzzy=True,                      # Fuzzy RDD
    order=3,                         # Polynomial order (from 1 to 4)
    plot_type='line', 
    treatment_variable = "treatment"              # Use 'scatter' or 'line'
)
# Out:
# {'first_stage': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
# ...
#  Dep. Variable:              treatment   R-squared:                       0.016
#  Model:                            OLS   Adj. R-squared:                  0.014
#  Method:                 Least Squares   F-statistic:                     6.924
#  Date:                Fri, 02 May 2025   Prob (F-statistic):           1.58e-05
#  Time:                        19:20:35   Log-Likelihood:                -1160.0
#  No. Observations:                1723   AIC:                             2330.
#  Df Residuals:                    1718   BIC:                             2357.
#  Df Model:                           4
#  Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
#  ------------------------------------------------------------------------------
# ...

# %%
# Define the values considered non-modern fuel
non_modern_values = [4, 6, 7, 8, 9, 11, 12, 99]

# Create modern_fuel variable
df['modern_fuel'] = np.where(df['S6AQ23'].isin(non_modern_values), 0, 1)

# %%
rdd_plot(
    data=df,
    outcome_variable='modern_fuel',  # Outcome variable
    running_variable='land',   # Running variable
    cutoff= 0.501,                       # Cutoff for RDD
    fuzzy=True,                      # Fuzzy RDD
    order=4,                         # Polynomial order (from 1 to 4)
    plot_type='line', 
    treatment_variable = "treatment"              # Use 'scatter' or 'line'
)
# Out:
# /opt/anaconda3/envs/notebook/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1782: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# {'first_stage': <class 'statsmodels.iolib.summary.Summary'>
#  """
#                              OLS Regression Results
# ...
#  Dep. Variable:              treatment   R-squared:                       0.016
#  Model:                            OLS   Adj. R-squared:                  0.013
#  Method:                 Least Squares   F-statistic:                     5.539
#  Date:                Fri, 02 May 2025   Prob (F-statistic):           4.56e-05
#  Time:                        19:24:32   Log-Likelihood:                -1160.0
#  No. Observations:                1723   AIC:                             2332.
#  Df Residuals:                    1717   BIC:                             2365.
#  Df Model:                           5
#  Covariance Type:            nonrobust
# ...
